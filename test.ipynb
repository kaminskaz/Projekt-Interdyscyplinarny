# %%
#pip install albumentations

# %%
#pip install --upgrade opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\zosia\.conda\envs\bhl\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\zosia\.conda\envs\bhl\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from Augumentor import Augumentor
# Out:
# c:\Users\Zosia\.conda\envs\bhl\Lib\site-packages\albumentations\check_version.py:107: UserWarning: Error fetching version info <urlopen error [Errno 11001] getaddrinfo failed>
#   data = fetch_version_info()

# %%
A = Augumentor()
A.process_image("img\dog_with_kid.jpg","output_img\dog_with_kid.jpg", 7,4,30)
# Out:
# Loaded image shape: (408, 612, 3), dtype: uint8
