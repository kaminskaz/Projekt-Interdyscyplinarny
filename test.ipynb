# %%
# !pip install --upgrade opencv-python albumentations

# %%
from Augumentor import Augumentor

# %%
A = Augumentor()

# %%
A.process_image("img/dog_with_kid.jpg","output_img/dog_with_kid_same.jpg", 7,4,30, mode="same")

# %%
A.process_image("img/dog_with_kid.jpg","output_img/dog_with_kid_different.jpg", 7,4,30, mode="different")

# %%
A.process_image("img/dog_with_kid.jpg","output_img/dog_with_kid_different.jpg", 7,4,30, mode="combine")
