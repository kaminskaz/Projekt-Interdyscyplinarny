# %%
# !pip install --upgrade opencv-python albumentations

# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
from Augmentor import Augmentor

# %%
A = Augmentor()

# %%
A.process_image(path="../../img/dog_with_kid.jpg",output_path="output_img/dog_with_kid_same.jpg", x_splits_number=7,y_splits_number=4,min_space_between_splits=10, mode="same")
# Out:
# <class 'int'> <class 'int'> <class 'int'> <class 'int'> <class 'int'>

# %%
A.process_image(path="../../img/dog_with_kid.jpg",output_path="output_img/dog_with_kid_same.jpg", x_splits_number=7,y_splits_number=4,min_space_between_splits=10, mode="different")
# Out:
# <class 'int'> <class 'int'> <class 'int'> <class 'int'> <class 'int'>

# %%
A.process_image(path="../../img/dog_with_kid.jpg",output_path="output_img/dog_with_kid_same.jpg", x_splits_number=7,y_splits_number=4,min_space_between_splits=10, mode="combine")
# Out:
# <class 'int'> <class 'int'> <class 'int'> <class 'int'> <class 'int'>
