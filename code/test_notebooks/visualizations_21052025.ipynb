# %%
from visualizations_new_func import plot_metrics_per_augmentation, get_best_avg_dfs_for_all_augmentations, plot_all_metrics_subplots, build_summary_dataframe

# %%
plot_metrics_per_augmentation(out_folder='out_21052025')

# %%
best_dfs = get_best_avg_dfs_for_all_augmentations(out_folder='out_21052025')
# Out:
# Wybrano folder: combine_13 dla augmentacji 'combine' z accuracy (test) = 85.9633
# Wybrano folder: flip-brightness_31 dla augmentacji 'flip-brightness' z accuracy (test) = 86.9033
# Wybrano folder: flip-rotate-brightness_13 dla augmentacji 'flip-rotate' z accuracy (test) = 87.0733
# Wybrano folder: flip-rotate-brightness_13 dla augmentacji 'rotate-brightness' z accuracy (test) = 87.0733
# Wybrano folder: flip-rotate-brightness_13 dla augmentacji 'flip-rotate-brightness' z accuracy (test) = 87.0733
# Obliczono średnią dla baseline z accuracy (test) = 84.1200
# Obliczono średnią dla stes z accuracy (test) = 86.3583

# %%
plot_all_metrics_subplots(best_dfs, out_folder='out_21052025')

# %%
df = build_summary_dataframe(out_folder='out_21052025')
df
# Out:
#                       Tryb liczba podziałów x liczba podziałów y  loss_mean  \
# 0                 baseline                  0                  0   0.607828
# 1                  combine                  0                  0   0.491760
# 2                  combine                  1                  1   0.497242
# 3                  combine                  1                  3   0.473406
# 4                  combine                  2                  2   0.479743
# 5                  combine                  3                  1   0.486917
# 6                  combine                  3                  3   0.486799
# 7                  combine                  9                  9   0.601601
# 8          flip-brightness                  0                  0   0.441931
# 9          flip-brightness                  1                  1   0.432600
# 10         flip-brightness                  1                  3   0.413913
# ...
